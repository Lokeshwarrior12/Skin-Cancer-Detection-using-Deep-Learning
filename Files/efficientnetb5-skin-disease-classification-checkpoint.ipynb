# %% [markdown]
# # ***GETTING OUR DATA READY***
#
# > Before going forward with modelling we need to split the data into train, test and validation to make it easy for modelling.
# For that we first install spilt_folders and then use it to split the input data in following ratio 80:10:10.

# %%
# !pip install split_folders
# Out:
# Requirement already satisfied: split_folders in c:\users\pythonfabhost\anaconda3\envs\rcnn\lib\site-packages (0.5.1)

# %%
import splitfolders
import os

# os.makedirs('output')
# os.makedirs('output/train')
# os.makedirs('output/val')
# os.makedirs('output/test')

loc = "IMG_CLASSES/"

splitfolders.ratio(loc,output = "output",seed = 42,ratio = (0.80,.1,.1))
# Out:
# Copying files: 272 files [00:04, 75.61 files/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fffcdcfbe7e1> in <module>
#       9 loc = "IMG_CLASSES/"
#      10
# ---> 11 splitfolders.ratio(loc,output = "output",seed = 42,ratio = (0.80,.1,.1))
#
# ~\anaconda3\envs\rcnn\lib\site-packages\splitfolders\split.py in ratio(input, output, seed, ratio, group_prefix, move)
#      92             prog_bar if use_tqdm else None,
#      93             group_prefix,
# ---> 94             move,
#      95         )
#      96
#
# ~\anaconda3\envs\rcnn\lib\site-packages\splitfolders\split.py in split_class_dir_ratio(class_dir, output, ratio, seed, prog_bar, group_prefix, move)
#     238
#     239     li = split_files(files, split_train_idx, split_val_idx, len(ratio) == 3)
# --> 240     copy_files(li, class_dir, output, prog_bar, move)
#     241
#     242
#
# ~\anaconda3\envs\rcnn\lib\site-packages\splitfolders\split.py in copy_files(files_type, class_dir, output, prog_bar, move)
#     312                     copy_fun(str(x), str(full_path))
#     313             else:
# --> 314                 copy_fun(str(f), str(full_path))
#
# ~\anaconda3\envs\rcnn\lib\shutil.py in copy2(src, dst, follow_symlinks)
#     255     if os.path.isdir(dst):
#     256         dst = os.path.join(dst, os.path.basename(src))
# --> 257     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     258     copystat(src, dst, follow_symlinks=follow_symlinks)
#     259     return dst
#
# ~\anaconda3\envs\rcnn\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# KeyboardInterrupt:

# %% [markdown]
# > In kaggle we need to create a directory for our data after splitting but if we do this using jupyter notebook on our PC/laptop,we can just specify the input path and output path.

# %%
import os
for dirpath,dirname,filename in os.walk("./output"):
    print(f"There are {len(dirname)} and {len(filename)} in '{dirpath}'.")
# Out:
# There are 3 and 0 in './output'.
# There are 10 and 0 in './output\test'.
# There are 0 and 169 in './output\test\1. Eczema 1677'.
# There are 0 and 211 in './output\test\10. Warts Molluscum and other Viral Infections - 2103'.
# There are 0 and 314 in './output\test\2. Melanoma 15.75k'.
# There are 0 and 127 in './output\test\3. Atopic Dermatitis - 1.25k'.
# There are 0 and 333 in './output\test\4. Basal Cell Carcinoma (BCC) 3323'.
# There are 0 and 797 in './output\test\5. Melanocytic Nevi (NV) - 7970'.
# There are 0 and 209 in './output\test\6. Benign Keratosis-like Lesions (BKL) 2624'.
# There are 0 and 206 in './output\test\7. Psoriasis pictures Lichen Planus and related diseases - 2k'.
# There are 0 and 186 in './output\test\8. Seborrheic Keratoses and other Benign Tumors - 1.8k'.
# There are 0 and 171 in './output\test\9. Tinea Ringworm Candidiasis and other Fungal Infections - 1.7k'.
# There are 10 and 0 in './output\train'.
# There are 0 and 1341 in './output\train\1. Eczema 1677'.
# There are 0 and 1682 in './output\train\10. Warts Molluscum and other Viral Infections - 2103'.
# There are 0 and 2512 in './output\train\2. Melanoma 15.75k'.
# There are 0 and 1005 in './output\train\3. Atopic Dermatitis - 1.25k'.
# There are 0 and 2658 in './output\train\4. Basal Cell Carcinoma (BCC) 3323'.
# There are 0 and 6376 in './output\train\5. Melanocytic Nevi (NV) - 7970'.
# There are 0 and 1663 in './output\train\6. Benign Keratosis-like Lesions (BKL) 2624'.
# There are 0 and 1644 in './output\train\7. Psoriasis pictures Lichen Planus and related diseases - 2k'.
# There are 0 and 1477 in './output\train\8. Seborrheic Keratoses and other Benign Tumors - 1.8k'.
# There are 0 and 1361 in './output\train\9. Tinea Ringworm Candidiasis and other Fungal Infections - 1.7k'.
# There are 10 and 0 in './output\val'.
# There are 0 and 167 in './output\val\1. Eczema 1677'.
# There are 0 and 210 in './output\val\10. Warts Molluscum and other Viral Infections - 2103'.
# There are 0 and 314 in './output\val\2. Melanoma 15.75k'.
# There are 0 and 125 in './output\val\3. Atopic Dermatitis - 1.25k'.
# There are 0 and 332 in './output\val\4. Basal Cell Carcinoma (BCC) 3323'.
# There are 0 and 797 in './output\val\5. Melanocytic Nevi (NV) - 7970'.
# There are 0 and 207 in './output\val\6. Benign Keratosis-like Lesions (BKL) 2624'.
# There are 0 and 205 in './output\val\7. Psoriasis pictures Lichen Planus and related diseases - 2k'.
# There are 0 and 184 in './output\val\8. Seborrheic Keratoses and other Benign Tumors - 1.8k'.
# There are 0 and 170 in './output\val\9. Tinea Ringworm Candidiasis and other Fungal Infections - 1.7k'.

# %% [markdown]
# > After modifying our input data and before the start of modelling its always best to visualize some random images of the dataset

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping
import random
import os
def plot_random_image(target_dir,target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder),1)
    img = mping.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off");
    return img

# %%
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(2,2,1)
img_1 = plot_random_image(target_dir = "./output/test/",target_class = "2. Melanoma 15.75k")
fig.add_subplot(2,2,2)
img_2 = plot_random_image(target_dir = "./output/test/",target_class = "4. Basal Cell Carcinoma (BCC) 3323")
fig.add_subplot(2,2,3)
img_3 = plot_random_image(target_dir = "./output/test/",target_class = "5. Melanocytic Nevi (NV) - 7970")
fig.add_subplot(2,2,4)
img4 = plot_random_image(target_dir = "./output/test/",target_class = "1. Eczema 1677")

# %% [markdown]
# # ***Modelling***

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce GTX 1650 Ti, compute capability 7.5

# %% [markdown]
# > When we use mixed_precision training the computation speed is increased by 3x times based on the GPU available. Mixed precision enables training using float16 half-precision variables whenever possible.

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

train_dir = "./output/train"
test_dir =  "./output/test"
val_dir = "./output/val"

train_data = image_dataset_from_directory(train_dir,label_mode = "categorical",
                                          image_size = (224,224),batch_size = 32,
                                         shuffle = True,seed = 42)
test_data = image_dataset_from_directory(test_dir,label_mode = "categorical",
                                          image_size = (224,224),batch_size = 32,
                                         shuffle = False,seed = 42)
val_data = image_dataset_from_directory(val_dir,label_mode = "categorical",
                                          image_size = (224,224),batch_size = 32,
                                         shuffle = False,seed = 42)
# Out:
# Found 21719 files belonging to 10 classes.
# Found 2723 files belonging to 10 classes.
# Found 2711 files belonging to 10 classes.

# %% [markdown]
# > image_dataset_from_directory() imports and converts our input data into tf.data.Dataset format and it is generally faster than ImageDataGenerator().

# %%
class_names = train_data.class_names
print(len(class_names))
print(class_names)
# Out:
# 10
# ['1. Eczema 1677', '10. Warts Molluscum and other Viral Infections - 2103', '2. Melanoma 15.75k', '3. Atopic Dermatitis - 1.25k', '4. Basal Cell Carcinoma (BCC) 3323', '5. Melanocytic Nevi (NV) - 7970', '6. Benign Keratosis-like Lesions (BKL) 2624', '7. Psoriasis pictures Lichen Planus and related diseases - 2k', '8. Seborrheic Keratoses and other Benign Tumors - 1.8k', '9. Tinea Ringworm Candidiasis and other Fungal Infections - 1.7k']

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor = "val_loss",patience = 6,
                                             min_delta = 0.0001)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = "val_loss",factor = 0.2,
                                                patience = 4,min_lr = 1e-7)

# %% [markdown]
# > * Earlystopping callback stops training when the model stops improving in terms of validation loss(in this case) and prevents overfitting.
# > * ReduceLROnPlateau reduces the learning rate by 5x(in this case) whenever validation loss is not improving.
# > * With the combination of Earlystopping and ReduceLROnPlateau callback when can train our model for any number of epochs without worrying about overfitting.

# %%
train_data = train_data.prefetch(buffer_size = tf.data.AUTOTUNE)
test_data = test_data.prefetch(buffer_size = tf.data.AUTOTUNE)
val_data = val_data.prefetch(buffer_size = tf.data.AUTOTUNE)

# %% [markdown]
# > Data is prefetched to reduce computation time.

# %%
base_model = tf.keras.applications.EfficientNetB5(include_top = False)
base_model.trainable = False

# %% [markdown]
# > First we are going to be training feature extractor EfficientNetB5 model. Feature extractor transfer learning involves using the pretrained weights of a model trained on another dataset similar to own for our own problem. Here the output layer of pretrained model is modified according our own problem.

# %%
for layer_num,layer in enumerate(base_model.layers):
    print(layer_num,layer.name,layer.trainable)
# Out:
# 0 input_1 False
# 1 rescaling False
# 2 normalization False
# 3 rescaling_1 False
# 4 stem_conv_pad False
# 5 stem_conv False
# 6 stem_bn False
# 7 stem_activation False
# 8 block1a_dwconv False
# 9 block1a_bn False
# 10 block1a_activation False
# 11 block1a_se_squeeze False
# 12 block1a_se_reshape False
# 13 block1a_se_reduce False
# 14 block1a_se_expand False
# 15 block1a_se_excite False
# 16 block1a_project_conv False
# 17 block1a_project_bn False
# 18 block1b_dwconv False
# 19 block1b_bn False
# 20 block1b_activation False
# 21 block1b_se_squeeze False
# 22 block1b_se_reshape False
# 23 block1b_se_reduce False
# 24 block1b_se_expand False
# 25 block1b_se_excite False
# 26 block1b_project_conv False
# 27 block1b_project_bn False
# 28 block1b_drop False
# 29 block1b_add False
# 30 block1c_dwconv False
# 31 block1c_bn False
# 32 block1c_activation False
# 33 block1c_se_squeeze False
# 34 block1c_se_reshape False
# 35 block1c_se_reduce False
# 36 block1c_se_expand False
# 37 block1c_se_excite False
# 38 block1c_project_conv False
# 39 block1c_project_bn False
# 40 block1c_drop False
# 41 block1c_add False
# 42 block2a_expand_conv False
# 43 block2a_expand_bn False
# 44 block2a_expand_activation False
# 45 block2a_dwconv_pad False
# 46 block2a_dwconv False
# 47 block2a_bn False
# 48 block2a_activation False
# 49 block2a_se_squeeze False
# 50 block2a_se_reshape False
# 51 block2a_se_reduce False
# 52 block2a_se_expand False
# 53 block2a_se_excite False
# 54 block2a_project_conv False
# 55 block2a_project_bn False
# 56 block2b_expand_conv False
# 57 block2b_expand_bn False
# 58 block2b_expand_activation False
# 59 block2b_dwconv False
# 60 block2b_bn False
# 61 block2b_activation False
# 62 block2b_se_squeeze False
# 63 block2b_se_reshape False
# 64 block2b_se_reduce False
# 65 block2b_se_expand False
# 66 block2b_se_excite False
# 67 block2b_project_conv False
# 68 block2b_project_bn False
# 69 block2b_drop False
# 70 block2b_add False
# 71 block2c_expand_conv False
# 72 block2c_expand_bn False
# 73 block2c_expand_activation False
# 74 block2c_dwconv False
# 75 block2c_bn False
# 76 block2c_activation False
# 77 block2c_se_squeeze False
# 78 block2c_se_reshape False
# 79 block2c_se_reduce False
# 80 block2c_se_expand False
# 81 block2c_se_excite False
# 82 block2c_project_conv False
# 83 block2c_project_bn False
# 84 block2c_drop False
# 85 block2c_add False
# 86 block2d_expand_conv False
# 87 block2d_expand_bn False
# 88 block2d_expand_activation False
# 89 block2d_dwconv False
# 90 block2d_bn False
# 91 block2d_activation False
# 92 block2d_se_squeeze False
# 93 block2d_se_reshape False
# 94 block2d_se_reduce False
# 95 block2d_se_expand False
# 96 block2d_se_excite False
# 97 block2d_project_conv False
# 98 block2d_project_bn False
# 99 block2d_drop False
# 100 block2d_add False
# 101 block2e_expand_conv False
# 102 block2e_expand_bn False
# 103 block2e_expand_activation False
# 104 block2e_dwconv False
# 105 block2e_bn False
# 106 block2e_activation False
# 107 block2e_se_squeeze False
# 108 block2e_se_reshape False
# 109 block2e_se_reduce False
# 110 block2e_se_expand False
# 111 block2e_se_excite False
# 112 block2e_project_conv False
# 113 block2e_project_bn False
# 114 block2e_drop False
# 115 block2e_add False
# 116 block3a_expand_conv False
# 117 block3a_expand_bn False
# 118 block3a_expand_activation False
# 119 block3a_dwconv_pad False
# 120 block3a_dwconv False
# 121 block3a_bn False
# 122 block3a_activation False
# 123 block3a_se_squeeze False
# 124 block3a_se_reshape False
# 125 block3a_se_reduce False
# 126 block3a_se_expand False
# 127 block3a_se_excite False
# 128 block3a_project_conv False
# 129 block3a_project_bn False
# 130 block3b_expand_conv False
# 131 block3b_expand_bn False
# 132 block3b_expand_activation False
# 133 block3b_dwconv False
# 134 block3b_bn False
# 135 block3b_activation False
# 136 block3b_se_squeeze False
# 137 block3b_se_reshape False
# 138 block3b_se_reduce False
# 139 block3b_se_expand False
# 140 block3b_se_excite False
# 141 block3b_project_conv False
# 142 block3b_project_bn False
# 143 block3b_drop False
# 144 block3b_add False
# 145 block3c_expand_conv False
# 146 block3c_expand_bn False
# 147 block3c_expand_activation False
# 148 block3c_dwconv False
# 149 block3c_bn False
# 150 block3c_activation False
# 151 block3c_se_squeeze False
# 152 block3c_se_reshape False
# 153 block3c_se_reduce False
# 154 block3c_se_expand False
# 155 block3c_se_excite False
# 156 block3c_project_conv False
# 157 block3c_project_bn False
# 158 block3c_drop False
# 159 block3c_add False
# 160 block3d_expand_conv False
# 161 block3d_expand_bn False
# 162 block3d_expand_activation False
# 163 block3d_dwconv False
# 164 block3d_bn False
# 165 block3d_activation False
# 166 block3d_se_squeeze False
# 167 block3d_se_reshape False
# 168 block3d_se_reduce False
# 169 block3d_se_expand False
# 170 block3d_se_excite False
# 171 block3d_project_conv False
# 172 block3d_project_bn False
# 173 block3d_drop False
# 174 block3d_add False
# 175 block3e_expand_conv False
# 176 block3e_expand_bn False
# 177 block3e_expand_activation False
# 178 block3e_dwconv False
# 179 block3e_bn False
# 180 block3e_activation False
# 181 block3e_se_squeeze False
# 182 block3e_se_reshape False
# 183 block3e_se_reduce False
# 184 block3e_se_expand False
# 185 block3e_se_excite False
# 186 block3e_project_conv False
# 187 block3e_project_bn False
# 188 block3e_drop False
# 189 block3e_add False
# 190 block4a_expand_conv False
# 191 block4a_expand_bn False
# 192 block4a_expand_activation False
# 193 block4a_dwconv_pad False
# 194 block4a_dwconv False
# 195 block4a_bn False
# 196 block4a_activation False
# 197 block4a_se_squeeze False
# 198 block4a_se_reshape False
# 199 block4a_se_reduce False
# 200 block4a_se_expand False
# 201 block4a_se_excite False
# 202 block4a_project_conv False
# 203 block4a_project_bn False
# 204 block4b_expand_conv False
# 205 block4b_expand_bn False
# 206 block4b_expand_activation False
# 207 block4b_dwconv False
# 208 block4b_bn False
# 209 block4b_activation False
# 210 block4b_se_squeeze False
# 211 block4b_se_reshape False
# 212 block4b_se_reduce False
# 213 block4b_se_expand False
# 214 block4b_se_excite False
# 215 block4b_project_conv False
# 216 block4b_project_bn False
# 217 block4b_drop False
# 218 block4b_add False
# 219 block4c_expand_conv False
# 220 block4c_expand_bn False
# 221 block4c_expand_activation False
# 222 block4c_dwconv False
# 223 block4c_bn False
# 224 block4c_activation False
# 225 block4c_se_squeeze False
# 226 block4c_se_reshape False
# 227 block4c_se_reduce False
# 228 block4c_se_expand False
# 229 block4c_se_excite False
# 230 block4c_project_conv False
# 231 block4c_project_bn False
# 232 block4c_drop False
# 233 block4c_add False
# 234 block4d_expand_conv False
# 235 block4d_expand_bn False
# 236 block4d_expand_activation False
# 237 block4d_dwconv False
# 238 block4d_bn False
# 239 block4d_activation False
# 240 block4d_se_squeeze False
# 241 block4d_se_reshape False
# 242 block4d_se_reduce False
# 243 block4d_se_expand False
# 244 block4d_se_excite False
# 245 block4d_project_conv False
# 246 block4d_project_bn False
# 247 block4d_drop False
# 248 block4d_add False
# 249 block4e_expand_conv False
# 250 block4e_expand_bn False
# 251 block4e_expand_activation False
# 252 block4e_dwconv False
# 253 block4e_bn False
# 254 block4e_activation False
# 255 block4e_se_squeeze False
# 256 block4e_se_reshape False
# 257 block4e_se_reduce False
# 258 block4e_se_expand False
# 259 block4e_se_excite False
# 260 block4e_project_conv False
# 261 block4e_project_bn False
# 262 block4e_drop False
# 263 block4e_add False
# 264 block4f_expand_conv False
# 265 block4f_expand_bn False
# 266 block4f_expand_activation False
# 267 block4f_dwconv False
# 268 block4f_bn False
# 269 block4f_activation False
# 270 block4f_se_squeeze False
# 271 block4f_se_reshape False
# 272 block4f_se_reduce False
# 273 block4f_se_expand False
# 274 block4f_se_excite False
# 275 block4f_project_conv False
# 276 block4f_project_bn False
# 277 block4f_drop False
# 278 block4f_add False
# 279 block4g_expand_conv False
# 280 block4g_expand_bn False
# 281 block4g_expand_activation False
# 282 block4g_dwconv False
# 283 block4g_bn False
# 284 block4g_activation False
# 285 block4g_se_squeeze False
# 286 block4g_se_reshape False
# 287 block4g_se_reduce False
# 288 block4g_se_expand False
# 289 block4g_se_excite False
# 290 block4g_project_conv False
# 291 block4g_project_bn False
# 292 block4g_drop False
# 293 block4g_add False
# 294 block5a_expand_conv False
# 295 block5a_expand_bn False
# 296 block5a_expand_activation False
# 297 block5a_dwconv False
# 298 block5a_bn False
# 299 block5a_activation False
# 300 block5a_se_squeeze False
# 301 block5a_se_reshape False
# 302 block5a_se_reduce False
# 303 block5a_se_expand False
# 304 block5a_se_excite False
# 305 block5a_project_conv False
# 306 block5a_project_bn False
# 307 block5b_expand_conv False
# 308 block5b_expand_bn False
# 309 block5b_expand_activation False
# 310 block5b_dwconv False
# 311 block5b_bn False
# 312 block5b_activation False
# 313 block5b_se_squeeze False
# 314 block5b_se_reshape False
# 315 block5b_se_reduce False
# 316 block5b_se_expand False
# 317 block5b_se_excite False
# 318 block5b_project_conv False
# 319 block5b_project_bn False
# 320 block5b_drop False
# 321 block5b_add False
# 322 block5c_expand_conv False
# 323 block5c_expand_bn False
# 324 block5c_expand_activation False
# 325 block5c_dwconv False
# 326 block5c_bn False
# 327 block5c_activation False
# 328 block5c_se_squeeze False
# 329 block5c_se_reshape False
# 330 block5c_se_reduce False
# 331 block5c_se_expand False
# 332 block5c_se_excite False
# 333 block5c_project_conv False
# 334 block5c_project_bn False
# 335 block5c_drop False
# 336 block5c_add False
# 337 block5d_expand_conv False
# 338 block5d_expand_bn False
# 339 block5d_expand_activation False
# 340 block5d_dwconv False
# 341 block5d_bn False
# 342 block5d_activation False
# 343 block5d_se_squeeze False
# 344 block5d_se_reshape False
# 345 block5d_se_reduce False
# 346 block5d_se_expand False
# 347 block5d_se_excite False
# 348 block5d_project_conv False
# 349 block5d_project_bn False
# 350 block5d_drop False
# 351 block5d_add False
# 352 block5e_expand_conv False
# 353 block5e_expand_bn False
# 354 block5e_expand_activation False
# 355 block5e_dwconv False
# 356 block5e_bn False
# 357 block5e_activation False
# 358 block5e_se_squeeze False
# 359 block5e_se_reshape False
# 360 block5e_se_reduce False
# 361 block5e_se_expand False
# 362 block5e_se_excite False
# 363 block5e_project_conv False
# 364 block5e_project_bn False
# 365 block5e_drop False
# 366 block5e_add False
# 367 block5f_expand_conv False
# 368 block5f_expand_bn False
# 369 block5f_expand_activation False
# 370 block5f_dwconv False
# 371 block5f_bn False
# 372 block5f_activation False
# 373 block5f_se_squeeze False
# 374 block5f_se_reshape False
# 375 block5f_se_reduce False
# 376 block5f_se_expand False
# 377 block5f_se_excite False
# 378 block5f_project_conv False
# 379 block5f_project_bn False
# 380 block5f_drop False
# 381 block5f_add False
# 382 block5g_expand_conv False
# 383 block5g_expand_bn False
# 384 block5g_expand_activation False
# 385 block5g_dwconv False
# 386 block5g_bn False
# 387 block5g_activation False
# 388 block5g_se_squeeze False
# 389 block5g_se_reshape False
# 390 block5g_se_reduce False
# 391 block5g_se_expand False
# 392 block5g_se_excite False
# 393 block5g_project_conv False
# 394 block5g_project_bn False
# 395 block5g_drop False
# 396 block5g_add False
# 397 block6a_expand_conv False
# 398 block6a_expand_bn False
# 399 block6a_expand_activation False
# 400 block6a_dwconv_pad False
# 401 block6a_dwconv False
# 402 block6a_bn False
# 403 block6a_activation False
# 404 block6a_se_squeeze False
# 405 block6a_se_reshape False
# 406 block6a_se_reduce False
# 407 block6a_se_expand False
# 408 block6a_se_excite False
# 409 block6a_project_conv False
# 410 block6a_project_bn False
# 411 block6b_expand_conv False
# 412 block6b_expand_bn False
# 413 block6b_expand_activation False
# 414 block6b_dwconv False
# 415 block6b_bn False
# 416 block6b_activation False
# 417 block6b_se_squeeze False
# 418 block6b_se_reshape False
# 419 block6b_se_reduce False
# 420 block6b_se_expand False
# 421 block6b_se_excite False
# 422 block6b_project_conv False
# 423 block6b_project_bn False
# 424 block6b_drop False
# 425 block6b_add False
# 426 block6c_expand_conv False
# 427 block6c_expand_bn False
# 428 block6c_expand_activation False
# 429 block6c_dwconv False
# 430 block6c_bn False
# 431 block6c_activation False
# 432 block6c_se_squeeze False
# 433 block6c_se_reshape False
# 434 block6c_se_reduce False
# 435 block6c_se_expand False
# 436 block6c_se_excite False
# 437 block6c_project_conv False
# 438 block6c_project_bn False
# 439 block6c_drop False
# 440 block6c_add False
# 441 block6d_expand_conv False
# 442 block6d_expand_bn False
# 443 block6d_expand_activation False
# 444 block6d_dwconv False
# 445 block6d_bn False
# 446 block6d_activation False
# 447 block6d_se_squeeze False
# 448 block6d_se_reshape False
# 449 block6d_se_reduce False
# 450 block6d_se_expand False
# 451 block6d_se_excite False
# 452 block6d_project_conv False
# 453 block6d_project_bn False
# 454 block6d_drop False
# 455 block6d_add False
# 456 block6e_expand_conv False
# 457 block6e_expand_bn False
# 458 block6e_expand_activation False
# 459 block6e_dwconv False
# 460 block6e_bn False
# 461 block6e_activation False
# 462 block6e_se_squeeze False
# 463 block6e_se_reshape False
# 464 block6e_se_reduce False
# 465 block6e_se_expand False
# 466 block6e_se_excite False
# 467 block6e_project_conv False
# 468 block6e_project_bn False
# 469 block6e_drop False
# 470 block6e_add False
# 471 block6f_expand_conv False
# 472 block6f_expand_bn False
# 473 block6f_expand_activation False
# 474 block6f_dwconv False
# 475 block6f_bn False
# 476 block6f_activation False
# 477 block6f_se_squeeze False
# 478 block6f_se_reshape False
# 479 block6f_se_reduce False
# 480 block6f_se_expand False
# 481 block6f_se_excite False
# 482 block6f_project_conv False
# 483 block6f_project_bn False
# 484 block6f_drop False
# 485 block6f_add False
# 486 block6g_expand_conv False
# 487 block6g_expand_bn False
# 488 block6g_expand_activation False
# 489 block6g_dwconv False
# 490 block6g_bn False
# 491 block6g_activation False
# 492 block6g_se_squeeze False
# 493 block6g_se_reshape False
# 494 block6g_se_reduce False
# 495 block6g_se_expand False
# 496 block6g_se_excite False
# 497 block6g_project_conv False
# 498 block6g_project_bn False
# 499 block6g_drop False
# 500 block6g_add False
# 501 block6h_expand_conv False
# 502 block6h_expand_bn False
# 503 block6h_expand_activation False
# 504 block6h_dwconv False
# 505 block6h_bn False
# 506 block6h_activation False
# 507 block6h_se_squeeze False
# 508 block6h_se_reshape False
# 509 block6h_se_reduce False
# 510 block6h_se_expand False
# 511 block6h_se_excite False
# 512 block6h_project_conv False
# 513 block6h_project_bn False
# 514 block6h_drop False
# 515 block6h_add False
# 516 block6i_expand_conv False
# 517 block6i_expand_bn False
# 518 block6i_expand_activation False
# 519 block6i_dwconv False
# 520 block6i_bn False
# 521 block6i_activation False
# 522 block6i_se_squeeze False
# 523 block6i_se_reshape False
# 524 block6i_se_reduce False
# 525 block6i_se_expand False
# 526 block6i_se_excite False
# 527 block6i_project_conv False
# 528 block6i_project_bn False
# 529 block6i_drop False
# 530 block6i_add False
# 531 block7a_expand_conv False
# 532 block7a_expand_bn False
# 533 block7a_expand_activation False
# 534 block7a_dwconv False
# 535 block7a_bn False
# 536 block7a_activation False
# 537 block7a_se_squeeze False
# 538 block7a_se_reshape False
# 539 block7a_se_reduce False
# 540 block7a_se_expand False
# 541 block7a_se_excite False
# 542 block7a_project_conv False
# 543 block7a_project_bn False
# 544 block7b_expand_conv False
# 545 block7b_expand_bn False
# 546 block7b_expand_activation False
# 547 block7b_dwconv False
# 548 block7b_bn False
# 549 block7b_activation False
# 550 block7b_se_squeeze False
# 551 block7b_se_reshape False
# 552 block7b_se_reduce False
# 553 block7b_se_expand False
# 554 block7b_se_excite False
# 555 block7b_project_conv False
# 556 block7b_project_bn False
# 557 block7b_drop False
# 558 block7b_add False
# 559 block7c_expand_conv False
# 560 block7c_expand_bn False
# 561 block7c_expand_activation False
# 562 block7c_dwconv False
# 563 block7c_bn False
# 564 block7c_activation False
# 565 block7c_se_squeeze False
# 566 block7c_se_reshape False
# 567 block7c_se_reduce False
# 568 block7c_se_expand False
# 569 block7c_se_excite False
# 570 block7c_project_conv False
# 571 block7c_project_bn False
# 572 block7c_drop False
# 573 block7c_add False
# 574 top_conv False
# 575 top_bn False
# 576 top_activation False

# %% [markdown]
# > As we can see EfficientNetB5 consists of 575 layers without including the output layer and the most important thing to note among these layers is the rescaling layer present right after the input layer,this means that we dont have to rescale our data during preprocessing.

# %%
from tensorflow.keras.layers.experimental import preprocessing

data_aug = tf.keras.Sequential([
    preprocessing.RandomWidth(0.2),
    preprocessing.RandomHeight(0.2),
    preprocessing.RandomRotation(0.2),
    preprocessing.RandomFlip("horizontal")
],name = "data_augmentation_layer")

# %% [markdown]
# > Data augmentation is used here to prevent overfitting, we can experiment without data augmentation and check whether the model overfits or not,but since we are using a transfer learning Architecture such as EfficientNet,its best to include data augmentation since the probability of our model overfitting is very high.

# %%
inputs = layers.Input(shape = (224,224,3),name = "input_layer")
x = data_aug(inputs)
x = base_model(x)
x = layers.GlobalAvgPool2D(name = "pooling_layer")(x)
x = layers.Dense(32,activation = "relu",kernel_initializer = tf.keras.initializers.he_normal())(x)
x = layers.Dense(10)(x)
outputs = layers.Activation("softmax",dtype = tf.float32)(x)
model = tf.keras.Model(inputs,outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation_layer (Se  (None, 224, 224, 3)      0
#  quential)
#
#  efficientnetb5 (Functional)  (None, None, None, 2048)  28513527
#
#  pooling_layer (GlobalAverag  (None, 2048)             0
#  ePooling2D)
#
#  dense (Dense)               (None, 32)                65568
#
#  dense_1 (Dense)             (None, 10)                330
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 28,579,425
# Trainable params: 65,898
# Non-trainable params: 28,513,527
# _________________________________________________________________

# %%
for layer_num,layer in enumerate(model.layers):
    print(layer_num,layer.name,layer.trainable,layer.dtype,layer.dtype_policy)
# Out:
# 0 input_layer True float32 <Policy "float32">
# 1 data_augmentation_layer True float32 <Policy "mixed_float16">
# 2 efficientnetb5 False float32 <Policy "mixed_float16">
# 3 pooling_layer True float32 <Policy "mixed_float16">
# 4 dense True float32 <Policy "mixed_float16">
# 5 dense_1 True float32 <Policy "mixed_float16">
# 6 activation True float32 <Policy "float32">

# %% [markdown]
# > We can clearly see here that mixed_precision policy is implemented and our EfficientNetB5 model is completely frozen. Now we can compile and fit our model.

# %%
model.compile(loss = tf.keras.losses.CategoricalCrossentropy(),optimizer = tf.keras.optimizers.Adam(),
             metrics = ["accuracy"])

# %%
history_1 = model.fit(train_data,epochs = 30,steps_per_epoch = len(train_data),
                     validation_data = val_data,validation_steps = int(0.25*len(val_data)),
                     callbacks = [early_stop,reduce_lr])
# Out:
# Epoch 1/30
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 679/679 [==============================] - 525s 735ms/step - loss: 1.0906 - accuracy: 0.5872 - val_loss: 1.2019 - val_accuracy: 0.5238 - lr: 0.0010
# Epoch 2/30
# 679/679 [==============================] - 466s 686ms/step - loss: 0.9194 - accuracy: 0.6508 - val_loss: 1.1026 - val_accuracy: 0.5670 - lr: 0.0010
# Epoch 3/30
# 679/679 [==============================] - 464s 684ms/step - loss: 0.8677 - accuracy: 0.6700 - val_loss: 0.9782 - val_accuracy: 0.6146 - lr: 0.0010
# Epoch 4/30
# 679/679 [==============================] - 463s 681ms/step - loss: 0.8281 - accuracy: 0.6890 - val_loss: 1.1094 - val_accuracy: 0.5685 - lr: 0.0010
# Epoch 5/30
# 679/679 [==============================] - 467s 687ms/step - loss: 0.8024 - accuracy: 0.6952 - val_loss: 1.0434 - val_accuracy: 0.6027 - lr: 0.0010
# Epoch 6/30
# 679/679 [==============================] - 472s 695ms/step - loss: 0.7772 - accuracy: 0.7093 - val_loss: 0.9961 - val_accuracy: 0.6071 - lr: 0.0010
# Epoch 7/30
# 679/679 [==============================] - 464s 683ms/step - loss: 0.7596 - accuracy: 0.7133 - val_loss: 1.0881 - val_accuracy: 0.5997 - lr: 0.0010
# Epoch 8/30
# 679/679 [==============================] - 459s 675ms/step - loss: 0.7138 - accuracy: 0.7322 - val_loss: 0.9840 - val_accuracy: 0.6131 - lr: 2.0000e-04
# Epoch 9/30
# 679/679 [==============================] - 461s 678ms/step - loss: 0.6946 - accuracy: 0.7436 - val_loss: 0.9921 - val_accuracy: 0.6235 - lr: 2.0000e-04

# %%
print("Validation Accuracy",model.evaluate(val_data))
print("Testing Accuracy",model.evaluate(test_data))
# Out:
# 85/85 [==============================] - 54s 629ms/step - loss: 0.7627 - accuracy: 0.7160
# Validation Accuracy [0.7626848816871643, 0.7159719467163086]
# 86/86 [==============================] - 55s 632ms/step - loss: 0.7682 - accuracy: 0.6996
# Testing Accuracy [0.7681707739830017, 0.6995960474014282]

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history_1)

# %% [markdown]
# > * Training Accuracy - 74.4%
# > * Testing Accuracy  - 71.2%
# > * Validation Accuracy - 71.7%
#
# > Note: Specified number of epochs as 15 but training stopped at 12 and it wasn't beacuse of earlystopping callback,not sure why it stopped early, if you got any ideas please do mention it.

# %% [markdown]
# # Fine-Tuned EfficientNetB5

# %%
base_model.trainable = True

for layer in base_model.layers[:-30]:
    layer.trainable = False

# %% [markdown]
# > Now in order to improve our model's performance we unfreeze the top 30 layers closer to the output layer and let them train on our data instead of using pre-trained weights.

# %%
for layer_num,layer in enumerate(model.layers):
    print(layer_num,layer.name,layer.trainable,layer.dtype_policy)

# %%
for layer_num,layer in enumerate(base_model.layers):
    print(layer_num,layer.name,layer.trainable)

# %%
model.compile(loss = tf.keras.losses.CategoricalCrossentropy(),optimizer = tf.keras.optimizers.Adam(1e-4),
             metrics = ["accuracy"])

# %%
history_2 = model.fit(train_data,epochs = 30,steps_per_epoch = len(train_data),
                     initial_epoch = history_1.epoch[-1],
                     validation_data = val_data,validation_steps = int(0.25*len(val_data)),
                     callbacks = [early_stop,reduce_lr])

# %%
print("Validation Accuracy",model.evaluate(val_data))
print("Testing Accuracy",model.evaluate(test_data))

# %%
def compare_historys(original_history, new_history, initial_epochs):
    """
    Compares two model history objects.
    """
    # Get original history measurements
    acc = original_history.history["accuracy"]
    loss = original_history.history["loss"]

    print(len(acc))

    val_acc = original_history.history["val_accuracy"]
    val_loss = original_history.history["val_loss"]

    # Combine original history with new history
    total_acc = acc + new_history.history["accuracy"]
    total_loss = loss + new_history.history["loss"]

    total_val_acc = val_acc + new_history.history["val_accuracy"]
    total_val_loss = val_loss + new_history.history["val_loss"]

    print(len(total_acc))
    print(total_acc)

    # Make plots
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(total_acc, label='Training Accuracy')
    plt.plot(total_val_acc, label='Validation Accuracy')
    plt.plot([initial_epochs-1, initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning') # reshift plot around epochs
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(total_loss, label='Training Loss')
    plt.plot(total_val_loss, label='Validation Loss')
    plt.plot([initial_epochs-1, initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning') # reshift plot around epochs
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

# %%
compare_historys(history_1,history_2,initial_epochs = 12)

# %% [markdown]
# > *  Training accuracy - 85.58%
# > *  Testing Accuracy - 77.08%
# > *  Validation Accuracy - 76.02%

# %% [markdown]
# # Model Evalutation

# %%
pred_probs = model.predict(test_data)
pred_probs[0]

# %%
pred_classes = pred_probs.argmax(axis =1)
print(pred_classes[0])
print(class_names[pred_classes[0]])

# %%
y_labels = []
for image,label in test_data.unbatch():
    y_labels.append(label.numpy().argmax())
y_labels[:20]

# %%
print(len(pred_classes))
print(len(y_labels))

# %%
from sklearn.metrics import classification_report
print("Classification report\n",classification_report(y_labels,pred_classes))

# %%
classification_dict = classification_report(y_labels,pred_classes,output_dict = True)
classification_dict

# %%
classification_f1_scores = {}
for k,v in classification_dict.items():
    if k == "accuracy":
        break
    else:
        classification_f1_scores[class_names[int(k)]] = v["f1-score"]
classification_f1_scores

# %%
f1_scores = pd.DataFrame({"class_name":list(classification_f1_scores.keys()),
                         "F1-Scores":list(classification_f1_scores.values())})
f1_scores.sort_values("F1-Scores",ascending = False)

# %% [markdown]
# > From the F1-Scores dataframe we can clearly see that our model perform best on Melanocytic Nevi with an F1-Score of 0.92 and perform the worst on Atopic Dematitis.

# %%
from sklearn.metrics import confusion_matrix
import itertools

def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
    norm: normalize values or not (default=False).
    savefig: save confusion matrix to file (default=False).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  ### Added: Rotate xticks for readability & increase font size (required due to such a large confusion matrix)
  plt.xticks(rotation=70, fontsize=text_size)
  plt.yticks(fontsize=text_size)

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if norm:
      plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)
    else:
      plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

  # Save the figure to the current working directory
  if savefig:
    fig.savefig("confusion_matrix.png")

# %%
make_confusion_matrix(y_labels,pred_classes,classes = class_names,figsize = (20,20))

# %% [markdown]
# * > From the confusion matrix we can clearly observe that the model is getting confused betwwen Melanocytic Nevi and Melanoma, Melanocyctic Nevi and Benign Kerotosis like Lesions, Tinea Ringworm Candidiasis and other Fungai Infections and Psoriasis pictures Lichen Planus and releated diseases.
# * > In order to examine why our model is getting confused between the above mentioned diseases we can look at the data ourselves or consult a doctor to find out whethere these disesase can be classified properly just by looking at their images, often when it comes to skin diseases it cannot be classified properly just by looking at the image further testing is required.

# %% [markdown]
# **Let us see what our most wrong predictions are to understand more about our model's performance**

# %%
filepaths = []
for filepath in test_data.list_files("./output/test/*/*.jpg", 
                                     shuffle=False):
  filepaths.append(filepath.numpy())
filepaths[:10]

# %%
len(filepaths)

# %%
prediction_df = pd.DataFrame({"img_path": filepaths,
                        "y_true": y_labels,
                        "y_pred": pred_classes,
                        "pred_conf": pred_probs.max(axis=1), # get the maximum prediction probability value
                        "y_true_classname": [class_names[i] for i in y_labels],
                        "y_pred_classname": [class_names[i] for i in pred_classes]}) 
prediction_df.head()

# %%
prediction_df["correct_pred"] = prediction_df["y_true"]==prediction_df["y_pred"]
prediction_df.head()

# %%
top_50_wrong = prediction_df[prediction_df["correct_pred"] == False].sort_values("pred_conf", ascending=False)[:50]
top_50_wrong.head(10)

# %% [markdown]
# > As we saw in our confusion matrix Benign Keratosis-Like Lesions and Melanocyctic Nevi is often misclassified by our model.

# %% [markdown]
# **Conclusion**
#
# > Transfer Learning architecture EfficientNetB5 works pretty well on the given dataset of 10 classes of skin diseases.But some of these diseases cannot be classified correctly just by looking at the images even by doctors so our model gets confused between different classes of diseases in our data. Currently it has a testing accuracy of 77% when trained for 21 epochs and it will improve if trained for another 10-15 epochs and it may get saturated around 80-85%.
# Now if we train on certain distinguishable classes in our data instead of all the 10 classes the same EfficientNetB5 would perform extremely well.

# %% [markdown]
# **Note:**
#
# > As I mentioned after feature extractor model training the training stopped even in fine tuned model around 21 epochs when it was supposed to train for 30 epochs and again it wasn't beacuse of earlystopping. My guess so for is my CPU ran out of memory in Kaggle and I am not sure why since I have implemented mixed_precision training. I generally work in Collab on all my projects and I have never had this problem before in Collab, am I bit new in implemented Deep Learning Models in Kaggle any suggestions to solve this problem and tips to make sure this doesn't happen in the future would greatly helpful.
#
# **Thank You**
